# %%
#Tri par Insertion

import time
import random

list_numbers = [random.randint(1, 1500) for x in range(1000)]

print("The list before: ")
print(list_numbers)

time_start = time.time()

for i in range(1, len(list_numbers)):
    for j in range(i):
        if list_numbers[i] < list_numbers[j]:
            num_temp = list_numbers[i]
            del list_numbers[i]
            list_numbers.insert(j, num_temp)
            break
            
time_end = time.time()
with open("time(Insertion).txt", "a") as file:
    time_execution = time_end - time_start
    file.write(str(time_execution))
    file.write("\n")

print(f"The total time is {time_end - time_start}\n")
print("The list after: ")
print(list_numbers)
# Out:
# The list before:
# [281, 186, 832, 567, 1477, 184, 1106, 501, 787, 1301, 1248, 682, 590, 179, 943, 266, 549, 774, 78, 390, 783, 1476, 916, 990, 325, 876, 804, 1297, 805, 824, 101, 894, 72, 266, 453, 1108, 1039, 1477, 1308, 1263, 211, 1139, 392, 27, 555, 1302, 984, 1358, 185, 714, 707, 1174, 951, 118, 992, 1330, 140, 583, 1374, 65, 968, 75, 1299, 1413, 217, 276, 117, 1006, 1323, 1241, 1313, 1327, 870, 608, 79, 429, 650, 1008, 472, 401, 972, 1427, 511, 867, 681, 332, 420, 172, 1129, 974, 1053, 1471, 629, 716, 353, 1417, 427, 1269, 1151, 743, 1002, 1337, 367, 617, 123, 231, 508, 546, 1088, 8, 756, 230, 153, 847, 696, 94, 396, 1018, 704, 1140, 407, 386, 838, 1321, 992, 124, 1411, 904, 377, 564, 164, 367, 330, 264, 9, 433, 983, 925, 995, 1294, 1455, 809, 791, 929, 521, 1096, 100, 120, 260, 380, 1189, 90, 1137, 798, 1208, 1213, 191, 1154, 855, 444, 440, 956, 926, 1405, 438, 107, 846, 103, 444, 1308, 856, 713, 1073, 26, 854, 1231, 860, 24, 875, 112, 921, 790, 1152, 1488, 653, 651, 1216, 843, 1482, 1314, 860, 595, 1017, 988, 1115, 423, 1459, 1224, 641, 1350, 1442, 1157, 1414, 269, 671, 720, 183, 500, 1173, 716, 370, 1015, 549, 1436, 528, 100, 1000, 714, 1330, 1091, 1219, 468, 925, 787, 1275, 718, 1242, 694, 1124, 431, 742, 533, 452, 1114, 810, 523, 125, 677, 1317, 1233, 1083, 948, 317, 372, 1489, 299, 1158, 877, 1273, 1165, 586, 1223, 435, 6, 431, 975, 285, 421, 591, 187, 1250, 1008, 309, 1213, 250, 79, 1256, 473, 620, 1186, 1286, 1482, 1071, 475, 699, 271, 450, 229, 323, 564, 1303, 799, 1073, 121, 1405, 723, 114, 1348, 581, 1415, 1182, 1151, 26, 1263, 410, 1104, 19, 1190, 619, 1283, 954, 599, 422, 1131, 68, 1055, 637, 754, 837, 298, 523, 435, 9, 171, 581, 1351, 702, 438, 1413, 528, 538, 1207, 88, 837, 145, 402, 1004, 518, 1181, 344, 611, 673, 46, 1351, 91, 1423, 1013, 370, 1412, 136, 1303, 939, 216, 688, 392, 1293, 593, 1446, 380, 415, 155, 1147, 755, 1437, 152, 1066, 1359, 614, 1232, 403, 671, 1306, 1123, 787, 638, 728, 277, 637, 574, 550, 1421, 972, 507, 529, 527, 232, 739, 1374, 1056, 1110, 264, 896, 1243,
927, 929, 931, 931, 938, 939, 940, 942, 943, 946, 948, 949, 951, 951, 951, 954, 955, 956, 956, 967, 968, 968, 969, 970, 972, 972, 974, 974, 974, 975, 975, 983, 984, 988, 990, 990, 992, 992, 994, 995, 995, 999, 1000, 1001, 1002, 1004, 1004, 1006, 1006, 1006, 1008, 1008, 1008, 1010, 1013, 1013, 1013, 1014, 1014, 1015, 1015, 1017, 1017, 1018, 1019, 1020, 1022, 1024, 1024, 1030, 1031, 1031, 1035, 1039, 1042, 1042, 1042, 1043, 1044, 1044, 1044, 1044, 1046, 1047, 1049, 1051, 1053, 1055, 1055, 1056, 1056, 1060, 1060, 1061, 1062, 1063, 1066, 1067, 1069, 1071, 1071, 1071, 1071, 1072, 1073, 1073, 1073, 1082, 1082, 1082, 1083, 1083, 1085, 1086, 1086, 1088, 1091, 1094, 1094, 1096, 1096, 1097, 1102, 1102, 1103, 1103, 1104, 1106, 1106, 1106, 1107, 1108, 1109, 1110, 1110, 1112, 1113, 1114, 1114, 1115, 1123, 1124, 1129, 1130, 1131, 1131, 1133, 1133, 1135, 1136, 1137, 1139, 1140, 1141, 1142, 1142, 1143, 1147, 1147, 1151, 1151, 1152, 1152, 1154, 1154, 1157, 1158, 1159, 1159, 1161, 1163, 1165, 1169, 1171, 1173, 1174, 1177, 1180, 1181,  ...

# %%
#Tri par Selection

import time
import random

list_numbers = [random.randint(1, 150) for x in range(100)]

print("The list before: ")
print(list_numbers)

time_start = time.time()

for i in range(0, len(list_numbers) - 1):
    num_min = list_numbers[i]
    for j in range(i + 1, len(list_numbers)):
        if num_min > list_numbers[j]:
            num_min = list_numbers[j]
            index_min = j
    list_numbers[i], list_numbers[index_min] = list_numbers[index_min], list_numbers[i]

time_end = time.time()
with open("time(Selection).txt", "a") as file:
    time_execution = time_end - time_start
    file.write(str(time_execution))
    file.write("\n")

print("The list after: ")
print(list_numbers)
# Out:
# The list before:
# [84, 140, 14, 141, 124, 48, 128, 73, 129, 133, 73, 17, 87, 19, 8, 126, 72, 140, 103, 55, 8, 77, 25, 60, 110, 24, 59, 55, 133, 75, 22, 124, 31, 51, 58, 81, 3, 67, 93, 127, 64, 64, 11, 15, 64, 12, 19, 90, 138, 78, 123, 11, 39, 3, 39, 63, 98, 16, 81, 36, 107, 7, 134, 27, 91, 95, 92, 62, 143, 25, 115, 28, 109, 94, 86, 137, 35, 16, 118, 3, 28, 72, 114, 90, 128, 144, 145, 113, 13, 2, 116, 36, 9, 132, 90, 138, 60, 142, 106, 121]
# Le temps pour le Tri par Selection pour la taille 100:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 24
#      22 with open("time.txt", "a") as file:
#      23     print(f"Le temps pour le Tri par Selection pour la taille {len(list_numbers)}: ")
# ---> 24     file.write(time_end - time_start)
#      25     file.write("\n")
#      27 print("The list after: ")
#
# TypeError: write() argument must be str, not float

# %%
#Recherche dichotomique

import time
import random

list_numbers = [random.randint(1, 150) for x in range(100)]
list_numbers.sort()
print("La list: ")
print(list_numbers)

def binary_search(numbers, start, end, num):
    if end < start:
        return -1
    middle = (start + end) // 2

    if num == numbers[middle]:
        return middle

    elif num < numbers[middle]:
        return binary_search(numbers, start, middle - 1, num)

    else:
        return binary_search(numbers, middle + 1, end, num)


time_start = time.time()

random_num = random.choice(list_numbers)
print(f"Le nombre random est {random_num}")
index = binary_search(list_numbers, 0, len(list_numbers), random_num)

time_end = time.time()
with open("time(dichotomie).txt", "a") as file:
    time_execution = time_end - time_start
    file.write(str(time_execution))
    file.write("\n")

print(f"The index of the number {random_num} is {index}")
# Out:
# La list:
# [1, 2, 5, 6, 7, 9, 10, 10, 11, 14, 14, 15, 16, 17, 22, 25, 25, 27, 28, 28, 32, 32, 32, 33, 35, 36, 36, 36, 36, 36, 37, 38, 39, 41, 41, 44, 45, 50, 53, 53, 56, 56, 57, 58, 59, 59, 61, 61, 65, 66, 67, 69, 69, 72, 72, 75, 75, 76, 81, 83, 83, 84, 87, 88, 90, 91, 91, 92, 94, 96, 98, 99, 101, 101, 109, 114, 115, 115, 117, 119, 120, 120, 121, 125, 126, 127, 128, 128, 134, 141, 142, 142, 144, 144, 144, 145, 146, 147, 147, 150]
# Le nombre random est 126
# Le temps pour la recherche dichotomique pour la taille 100:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 35
#      33 with open("time.txt", "a") as file:
#      34     print(f"Le temps pour la recherche dichotomique pour la taille {len(list_numbers)}: ")
# ---> 35     file.write(time_end - time_start)
#      36     file.write("\n")
#      38 print(f"The index of the number {random_num} is {index}")
#
# TypeError: write() argument must be str, not float

# %%
#Tri par Bulles

import time
import random

list_numbers = [random.randint(1, 150) for x in range(100)]

print("The list before: ")
print(list_numbers)

time_start = time.time()

for i in range(len(list_numbers) - 1):
    for j in range(len(list_numbers) - i - 1):
        if list_numbers[j] > list_numbers[j + 1]:
            list_numbers[j], list_numbers[j + 1] = list_numbers[j + 1], list_numbers[j]
            
time_end = time.time()
with open("time(Bulles).txt", "a") as file:
    time_execution = time_end - time_start
    file.write(str(time_execution))
    file.write("\n")

print(f"The total time is {time_end - time_start}\n")
print("The list after: ")
print(list_numbers)
# Out:
# The list before:
# [4, 13, 9, 11, 9, 3, 4, 6, 9, 10]
# The total time is 0.0012640953063964844
#
# The list after:
# [3, 4, 4, 6, 9, 9, 9, 10, 11, 13]

# %%
#Tri par Tas

import time
import random

def heapify(numbers, n, i):
    root = i
    left = 2 * i + 1
    right = 2 * i + 2

    if left < n and numbers[left] > numbers[root]:
        root = left

    if right < n and numbers[right] > numbers[root]:
        root = right

    if root != i:
        numbers[i], numbers[root] = numbers[root], numbers[i]
        heapify(numbers, n, root)

def heap_sort(numbers):
    n = len(numbers)

    for i in range(n // 2 - 1, -1, -1):
        heapify(numbers, n, i)

    for i in range(n - 1, 0, -1):
        numbers[i], numbers[0] = numbers[0], numbers[i]
        heapify(numbers, i, 0)



list_numbers = [random.randint(1, 150) for x in range(100)]

print("The list before: ")
print(list_numbers)

time_start = time.time()

heap_sort(list_numbers)
            
time_end = time.time()
with open("time(Bulles).txt", "a") as file:
    time_execution = time_end - time_start
    file.write(str(time_execution))
    file.write("\n")

print(f"The total time is {time_end - time_start}\n")
print("The list after: ")
print(list_numbers)
# Out:
# The list before:
# [117, 39, 72, 39, 41, 143, 121, 86, 56, 97, 19, 46, 54, 125, 120, 78, 112, 80, 32, 117, 67, 79, 72, 89, 61, 117, 106, 1, 131, 104, 129, 143, 16, 99, 11, 87, 129, 23, 28, 49, 68, 40, 74, 110, 47, 92, 122, 37, 86, 111, 108, 53, 97, 24, 47, 65, 129, 93, 54, 63, 6, 105, 95, 68, 92, 122, 115, 50, 109, 72, 39, 118, 95, 89, 32, 3, 111, 102, 132, 101, 123, 83, 138, 142, 5, 63, 28, 74, 36, 43, 40, 103, 68, 30, 49, 47, 87, 79, 57, 77]
# The total time is 0.00013136863708496094
#
# The list after:
# [1, 3, 5, 6, 11, 16, 19, 23, 24, 28, 28, 30, 32, 32, 36, 37, 39, 39, 39, 40, 40, 41, 43, 46, 47, 47, 47, 49, 49, 50, 53, 54, 54, 56, 57, 61, 63, 63, 65, 67, 68, 68, 68, 72, 72, 72, 74, 74, 77, 78, 79, 79, 80, 83, 86, 86, 87, 87, 89, 89, 92, 92, 93, 95, 95, 97, 97, 99, 101, 102, 103, 104, 105, 106, 108, 109, 110, 111, 111, 112, 115, 117, 117, 117, 118, 120, 121, 122, 122, 123, 125, 129, 129, 129, 131, 132, 138, 142, 143, 143]

# %%
#Tri par Fusion

import time
import random

def merge_sort(numbers):
    if len(numbers) <= 1:
        return numbers

    mid = len(numbers) // 2
    left_half = merge_sort(numbers[:mid])
    right_half = merge_sort(numbers[mid:])

    return merge(left_half, right_half)

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result



list_numbers = [random.randint(1, 150) for x in range(100)]

print("The list before: ")
print(list_numbers)

time_start = time.time()

list_numbers_sorted = merge_sort(list_numbers)
            
time_end = time.time()
# with open("time(Fusion).txt", "a") as file:
#     time_execution = time_end - time_start
#     file.write(str(time_execution))
#     file.write("\n")

print(f"The total time is {time_end - time_start}\n")
print("The list after: ")
print(list_numbers_sorted)
# Out:
# The list before:
# [109, 29, 25, 22, 55, 125, 25, 80, 40, 123, 19, 69, 62, 47, 142, 40, 128, 12, 124, 40, 43, 25, 4, 68, 144, 148, 29, 1, 63, 47, 141, 52, 116, 1, 92, 2, 6, 150, 75, 101, 99, 124, 109, 88, 126, 32, 62, 28, 97, 101, 87, 134, 84, 51, 132, 88, 102, 93, 133, 78, 77, 144, 94, 74, 125, 134, 92, 14, 140, 150, 56, 51, 116, 16, 43, 60, 51, 105, 122, 140, 115, 74, 108, 3, 130, 142, 46, 27, 126, 149, 66, 59, 129, 69, 55, 143, 97, 71, 77, 100]
# The total time is 0.0009367465972900391
#
# The list after:
# [1, 1, 2, 3, 4, 6, 12, 14, 16, 19, 22, 25, 25, 25, 27, 28, 29, 29, 32, 40, 40, 40, 43, 43, 46, 47, 47, 51, 51, 51, 52, 55, 55, 56, 59, 60, 62, 62, 63, 66, 68, 69, 69, 71, 74, 74, 75, 77, 77, 78, 80, 84, 87, 88, 88, 92, 92, 93, 94, 97, 97, 99, 100, 101, 101, 102, 105, 108, 109, 109, 115, 116, 116, 122, 123, 124, 124, 125, 125, 126, 126, 128, 129, 130, 132, 133, 134, 134, 140, 140, 141, 142, 142, 143, 144, 144, 148, 149, 150, 150]
